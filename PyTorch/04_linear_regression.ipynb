# %%
import torch
from torch.autograd import Variable

# %% [markdown]
# ## data definition (3*1)

# %%
x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0]]))
y_data = Variable(torch.Tensor([[2.0], [4.0], [6.0]]))
'''
x    y
1.0  2.0
2.0  4.0
3.0  6.0
'''

# %% [markdown]
# ## Model class in PyTorch way

# %%
class Model(torch.nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.linear = torch.nn.Linear(1,1)
    
    def forward(self, x):
        y_pred = self.linear(x)
        return y_pred
    
model = Model()

# %% [markdown]
# ## Construct loss and optimizer

# %%
criterion = torch.nn.MSELoss(size_average=False)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01)

# %% [markdown]
# ## Before training
# ##### the answer is 8

# %%
print(model(Variable(torch.Tensor([[4.0]]))))
# Out:
# tensor([[ 1.2269]])

# %% [markdown]
# ## Training loop

# %%
for epoch in range(500):
    y_pred = model(x_data)
    loss = criterion(y_pred, y_data)
    print(epoch, loss.data[0])
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# D:\Anaconda3\envs\pytorch\lib\site-packages\ipykernel_launcher.py:4: UserWarning: invalid index of a 0-dim tensor. This will be an error in PyTorch 0.5. Use tensor.item() to convert a 0-dim tensor to a Python number
#   after removing the cwd from sys.path.
# 0 tensor(47.2039)
# 1 tensor(21.0159)
# 2 tensor(9.3577)
# 3 tensor(4.1678)
# 4 tensor(1.8574)
# 5 tensor(0.8288)
# 6 tensor(0.3709)
# 7 tensor(0.1670)
# 8 tensor(1.00000e-02 *
#        7.6218)
# 9 tensor(1.00000e-02 *
#        3.5774)
# 10 tensor(1.00000e-02 *
#        1.7743)
# 11 tensor(1.00000e-03 *
#        9.6906)
# 12 tensor(1.00000e-03 *
#        6.0800)
# 13 tensor(1.00000e-03 *
#        4.4472)
# 14 tensor(1.00000e-03 *
#        3.6954)
# 15 tensor(1.00000e-03 *
#        3.3360)
# 16 tensor(1.00000e-03 *
#        3.1517)
# 17 tensor(1.00000e-03 *
#        3.0458)
# 18 tensor(1.00000e-03 *
#        2.9750)
# 19 tensor(1.00000e-03 *
#        2.9202)
# 20 tensor(1.00000e-03 *
#        2.8729)
# 21 tensor(1.00000e-03 *
#        2.8292)
# 22 tensor(1.00000e-03 *
#        2.7875)
# 23 tensor(1.00000e-03 *
#        2.7469)
# 24 tensor(1.00000e-03 *
#        2.7072)
# 25 tensor(1.00000e-03 *
#        2.6682)
# 26 tensor(1.00000e-03 *
#        2.6298)
# 27 tensor(1.00000e-03 *
#        2.5920)
# 28 tensor(1.00000e-03 *
#        2.5548)
# 29 tensor(1.00000e-03 *
#        2.5181)
# 30 tensor(1.00000e-03 *
#        2.4819)
# 31 tensor(1.00000e-03 *
#        2.4462)
# 32 tensor(1.00000e-03 *
#        2.4110)
# 33 tensor(1.00000e-03 *
#        2.3764)
# 34 tensor(1.00000e-03 *
#        2.3422)
# 35 tensor(1.00000e-03 *
#        2.3086)
# 36 tensor(1.00000e-03 *
#        2.2754)
# 37 tensor(1.00000e-03 *
#        2.2427)
# 38 tensor(1.00000e-03 *
#        2.2105)
# 39 tensor(1.00000e-03 *
#        2.1787)
# 40 tensor(1.00000e-03 *
#        2.1474)
# 41 tensor(1.00000e-03 *
#        2.1165)
# 42 tensor(1.00000e-03 *
#        2.0861)
# 43 tensor(1.00000e-03 *
#        2.0561)
# 44 tensor(1.00000e-03 *
#        2.0266)
# 45 tensor(1.00000e-03 *
#        1.9975)
# 46 tensor(1.00000e-03 *
#        1.9688)
# 47 tensor(1.00000e-03 *
#        1.9405)
# 48 tensor(1.00000e-03 *
#        1.9126)
# 49 tensor(1.00000e-03 *
#        1.8851)
# 50 tensor(1.00000e-03 *
#        1.8580)
# 51 tensor(1.00000e-03 *
#        1.8313)
# 52 tensor(1.00000e-03 *
#        1.8050)
# 53 tensor(1.00000e-03 *
#        1.7790)
# 54 tensor(1.00000e-03 *
#        1.7535)
# 55 tensor(1.00000e-03 *
#        1.7282)
# 56 tensor(1.00000e-03 *
#        1.7034)
# 57 tensor(1.00000e-03 *
#        1.6789)
# 58 tensor(1.00000e-03 *
#        1.6548)
# 59 tensor(1.00000e-03 *
#        1.6310)
# 60 tensor(1.00000e-03 *
#        1.6076)
# 61 tensor(1.00000e-03 *
#        1.5845)
# 62 tensor(1.00000e-03 *
#        1.5617)
# 63 tensor(1.00000e-03 *
#        1.5393)
# 64 tensor(1.00000e-03 *
#        1.5172)
# 65 tensor(1.00000e-03 *
#        1.4953)
# 66 tensor(1.00000e-03 *
#        1.4738)
# 67 tensor(1.00000e-03 *
#        1.4527)
# 68 tensor(1.00000e-03 *
#        1.4318)
# 69 tensor(1.00000e-03 *
#        1.4112)
# 70 tensor(1.00000e-03 *
#        1.3909)
# 71 tensor(1.00000e-03 *
#        1.3710)
# 72 tensor(1.00000e-03 *
#        1.3512)
# 73 tensor(1.00000e-03 *
#        1.3318)
# 74 tensor(1.00000e-03 *
#        1.3127)
# 75 tensor(1.00000e-03 *
#        1.2938)
# 76 tensor(1.00000e-03 *
#        1.2752)
# 77 tensor(1.00000e-03 *
#        1.2569)
# 78 tensor(1.00000e-03 *
#        1.2388)
# 79 tensor(1.00000e-03 *
#        1.2210)
# 80 tensor(1.00000e-03 *
#        1.2035)
# 81 tensor(1.00000e-03 *
#        1.1862)
# 82 tensor(1.00000e-03 *
#        1.1691)
# 83 tensor(1.00000e-03 *
#        1.1523)
# 84 tensor(1.00000e-03 *
#        1.1358)
# 85 tensor(1.00000e-03 *
#        1.1195)
# 86 tensor(1.00000e-03 *
#        1.1034)
# 87 tensor(1.00000e-03 *
#        1.0875)
# 88 tensor(1.00000e-03 *
#        1.0719)
# 89 tensor(1.00000e-03 *
#        1.0565)
# 90 tensor(1.00000e-03 *
#        1.0413)
# 91 tensor(1.00000e-03 *
#        1.0263)
# 92 tensor(1.00000e-03 *
#        1.0116)
# 93 tensor(1.00000e-04 *
#        9.9704)
# 94 tensor(1.00000e-04 *
#        9.8271)
# 95 tensor(1.00000e-04 *
#        9.6857)
# 96 tensor(1.00000e-04 *
#        9.5467)
# 97 tensor(1.00000e-04 *
#        9.4094)
# 98 tensor(1.00000e-04 *
#        9.2741)
# 99 tensor(1.00000e-04 *
#        9.1409)
# 100 tensor(1.00000e-04 *
#        9.0096)
# 101 tensor(1.00000e-04 *
#        8.8800)
# 102 tensor(1.00000e-04 *
#        8.7524)
# 103 tensor(1.00000e-04 *
#        8.6267)
# 104 tensor(1.00000e-04 *
#        8.5026)
# 105 tensor(1.00000e-04 *
#        8.3805)
# 106 tensor(1.00000e-04 *
#        8.2600)
# 107 tensor(1.00000e-04 *
#        8.1413)
# 108 tensor(1.00000e-04 *
#        8.0243)
# 109 tensor(1.00000e-04 *
#        7.9090)
# 110 tensor(1.00000e-04 *
#        7.7953)
# 111 tensor(1.00000e-04 *
#        7.6834)
# 112 tensor(1.00000e-04 *
#        7.5729)
# 113 tensor(1.00000e-04 *
#        7.4641)
# 114 tensor(1.00000e-04 *
#        7.3568)
# 115 tensor(1.00000e-04 *
#        7.2511)
# 116 tensor(1.00000e-04 *
#        7.1469)
# 117 tensor(1.00000e-04 *
#        7.0441)
# 118 tensor(1.00000e-04 *
#        6.9430)
# 119 tensor(1.00000e-04 *
#        6.8432)
# 120 tensor(1.00000e-04 *
#        6.7448)
# 121 tensor(1.00000e-04 *
#        6.6478)
# 122 tensor(1.00000e-04 *
#        6.5524)
# 123 tensor(1.00000e-04 *
#        6.4582)
# 124 tensor(1.00000e-04 *
#        6.3653)
# 125 tensor(1.00000e-04 *
#        6.2739)
# 126 tensor(1.00000e-04 *
#        6.1837)
# 127 tensor(1.00000e-04 *
#        6.0948)
# 128 tensor(1.00000e-04 *
#        6.0073)
# 129 tensor(1.00000e-04 *
#        5.9210)
# 130 tensor(1.00000e-04 *
#        5.8358)
# 131 tensor(1.00000e-04 *
#        5.7519)
# 132 tensor(1.00000e-04 *
#        5.6692)
# 133 tensor(1.00000e-04 *
#        5.5878)
# 134 tensor(1.00000e-04 *
#        5.5075)
# 135 tensor(1.00000e-04 *
#        5.4284)
# 136 tensor(1.00000e-04 *
#        5.3503)
# 137 tensor(1.00000e-04 *
#        5.2734)
# 138 tensor(1.00000e-04 *
#        5.1977)
# 139 tensor(1.00000e-04 *
#        5.1230)
# 140 tensor(1.00000e-04 *
#        5.0493)
# 141 tensor(1.00000e-04 *
#        4.9767)
# 142 tensor(1.00000e-04 *
#        4.9052)
# 143 tensor(1.00000e-04 *
#        4.8347)
# 144 tensor(1.00000e-04 *
#        4.7653)
# 145 tensor(1.00000e-04 *
#        4.6969)
# 146 tensor(1.00000e-04 *
#        4.6293)
# 147 tensor(1.00000e-04 *
#        4.5628)
# 148 tensor(1.00000e-04 *
#        4.4972)
# 149 tensor(1.00000e-04 *
#        4.4326)
# 150 tensor(1.00000e-04 *
#        4.3688)
# 151 tensor(1.00000e-04 *
#        4.3061)
# 152 tensor(1.00000e-04 *
#        4.2442)
# 153 tensor(1.00000e-04 *
#        4.1832)
# 154 tensor(1.00000e-04 *
#        4.1231)
# 155 tensor(1.00000e-04 *
#        4.0639)
# 156 tensor(1.00000e-04 *
#        4.0055)
# 157 tensor(1.00000e-04 *
#        3.9478)
# 158 tensor(1.00000e-04 *
#        3.8911)
# 159 tensor(1.00000e-04 *
#        3.8351)
# 160 tensor(1.00000e-04 *
#        3.7800)
# 161 tensor(1.00000e-04 *
#        3.7258)
# 162 tensor(1.00000e-04 *
#        3.6722)
# 163 tensor(1.00000e-04 *
#        3.6193)
# 164 tensor(1.00000e-04 *
#        3.5674)
# 165 tensor(1.00000e-04 *
#        3.5162)
# 166 tensor(1.00000e-04 *
#        3.4656)
# 167 tensor(1.00000e-04 *
#        3.4158)
# 168 tensor(1.00000e-04 *
#        3.3667)
# 169 tensor(1.00000e-04 *
#        3.3183)
# 170 tensor(1.00000e-04 *
#        3.2706)
# 171 tensor(1.00000e-04 *
#        3.2236)
# 172 tensor(1.00000e-04 *
#        3.1773)
# 173 tensor(1.00000e-04 *
#        3.1316)
# 174 tensor(1.00000e-04 *
#        3.0866)
# 175 tensor(1.00000e-04 *
#        3.0423)
# 176 tensor(1.00000e-04 *
#        2.9985)
# 177 tensor(1.00000e-04 *
#        2.9553)
# 178 tensor(1.00000e-04 *
#        2.9130)
# 179 tensor(1.00000e-04 *
#        2.8711)
# 180 tensor(1.00000e-04 *
#        2.8298)
# 181 tensor(1.00000e-04 *
#        2.7891)
# 182 tensor(1.00000e-04 *
#        2.7491)
# 183 tensor(1.00000e-04 *
#        2.7096)
# 184 tensor(1.00000e-04 *
#        2.6707)
# 185 tensor(1.00000e-04 *
#        2.6322)
# 186 tensor(1.00000e-04 *
#        2.5944)
# 187 tensor(1.00000e-04 *
#        2.5571)
# 188 tensor(1.00000e-04 *
#        2.5203)
# 189 tensor(1.00000e-04 *
#        2.4842)
# 190 tensor(1.00000e-04 *
#        2.4485)
# 191 tensor(1.00000e-04 *
#        2.4132)
# 192 tensor(1.00000e-04 *
#        2.3787)
# 193 tensor(1.00000e-04 *
#        2.3444)
# 194 tensor(1.00000e-04 *
#        2.3107)
# 195 tensor(1.00000e-04 *
#        2.2775)
# 196 tensor(1.00000e-04 *
#        2.2447)
# 197 tensor(1.00000e-04 *
#        2.2125)
# 198 tensor(1.00000e-04 *
#        2.1808)
# 199 tensor(1.00000e-04 *
#        2.1494)
# 200 tensor(1.00000e-04 *
#        2.1185)
# 201 tensor(1.00000e-04 *
#        2.0881)
# 202 tensor(1.00000e-04 *
#        2.0580)
# 203 tensor(1.00000e-04 *
#        2.0285)
# 204 tensor(1.00000e-04 *
#        1.9993)
# 205 tensor(1.00000e-04 *
#        1.9706)
# 206 tensor(1.00000e-04 *
#        1.9423)
# 207 tensor(1.00000e-04 *
#        1.9144)
# 208 tensor(1.00000e-04 *
#        1.8869)
# 209 tensor(1.00000e-04 *
#        1.8597)
# 210 tensor(1.00000e-04 *
#        1.8330)
# 211 tensor(1.00000e-04 *
#        1.8066)
# 212 tensor(1.00000e-04 *
#        1.7806)
# 213 tensor(1.00000e-04 *
#        1.7551)
# 214 tensor(1.00000e-04 *
#        1.7298)
# 215 tensor(1.00000e-04 *
#        1.7050)
# 216 tensor(1.00000e-04 *
#        1.6804)
# 217 tensor(1.00000e-04 *
#        1.6563)
# 218 tensor(1.00000e-04 *
#        1.6325)
# 219 tensor(1.00000e-04 *
#        1.6091)
# 220 tensor(1.00000e-04 *
#        1.5859)
# 221 tensor(1.00000e-04 *
#        1.5631)
# 222 tensor(1.00000e-04 *
#        1.5407)
# 223 tensor(1.00000e-04 *
#        1.5185)
# 224 tensor(1.00000e-04 *
#        1.4967)
# 225 tensor(1.00000e-04 *
#        1.4752)
# 226 tensor(1.00000e-04 *
#        1.4540)
# 227 tensor(1.00000e-04 *
#        1.4331)
# 228 tensor(1.00000e-04 *
#        1.4125)
# 229 tensor(1.00000e-04 *
#        1.3922)
# 230 tensor(1.00000e-04 *
#        1.3722)
# 231 tensor(1.00000e-04 *
#        1.3525)
# 232 tensor(1.00000e-04 *
#        1.3330)
# 233 tensor(1.00000e-04 *
#        1.3138)
# 234 tensor(1.00000e-04 *
#        1.2950)
# 235 tensor(1.00000e-04 *
#        1.2764)
# 236 tensor(1.00000e-04 *
#        1.2581)
# 237 tensor(1.00000e-04 *
#        1.2400)
# 238 tensor(1.00000e-04 *
#        1.2221)
# 239 tensor(1.00000e-04 *
#        1.2046)
# 240 tensor(1.00000e-04 *
#        1.1873)
# 241 tensor(1.00000e-04 *
#        1.1702)
# 242 tensor(1.00000e-04 *
#        1.1534)
# 243 tensor(1.00000e-04 *
#        1.1368)
# 244 tensor(1.00000e-04 *
#        1.1204)
# 245 tensor(1.00000e-04 *
#        1.1044)
# 246 tensor(1.00000e-04 *
#        1.0885)
# 247 tensor(1.00000e-04 *
#        1.0729)
# 248 tensor(1.00000e-04 *
#        1.0574)
# 249 tensor(1.00000e-04 *
#        1.0422)
# 250 tensor(1.00000e-04 *
#        1.0273)
# 251 tensor(1.00000e-04 *
#        1.0125)
# 252 tensor(1.00000e-05 *
#        9.9791)
# 253 tensor(1.00000e-05 *
#        9.8362)
# 254 tensor(1.00000e-05 *
#        9.6943)
# 255 tensor(1.00000e-05 *
#        9.5549)
# 256 tensor(1.00000e-05 *
#        9.4180)
# 257 tensor(1.00000e-05 *
#        9.2830)
# 258 tensor(1.00000e-05 *
#        9.1492)
# 259 tensor(1.00000e-05 *
#        9.0175)
# 260 tensor(1.00000e-05 *
#        8.8876)
# 261 tensor(1.00000e-05 *
#        8.7605)
# 262 tensor(1.00000e-05 *
#        8.6342)
# 263 tensor(1.00000e-05 *
#        8.5105)
# 264 tensor(1.00000e-05 *
#        8.3877)
# 265 tensor(1.00000e-05 *
#        8.2674)
# 266 tensor(1.00000e-05 *
#        8.1489)
# 267 tensor(1.00000e-05 *
#        8.0316)
# 268 tensor(1.00000e-05 *
#        7.9162)
# 269 tensor(1.00000e-05 *
#        7.8023)
# 270 tensor(1.00000e-05 *
#        7.6900)
# 271 tensor(1.00000e-05 *
#        7.5799)
# 272 tensor(1.00000e-05 *
#        7.4708)
# 273 tensor(1.00000e-05 *
#        7.3636)
# 274 tensor(1.00000e-05 *
#        7.2573)
# 275 tensor(1.00000e-05 *
#        7.1531)
# 276 tensor(1.00000e-05 *
#        7.0504)
# 277 tensor(1.00000e-05 *
#        6.9489)
# 278 tensor(1.00000e-05 *
#        6.8497)
# 279 tensor(1.00000e-05 *
#        6.7510)
# 280 tensor(1.00000e-05 *
#        6.6540)
# 281 tensor(1.00000e-05 *
#        6.5585)
# 282 tensor(1.00000e-05 *
#        6.4640)
# 283 tensor(1.00000e-05 *
#        6.3712)
# 284 tensor(1.00000e-05 *
#        6.2797)
# 285 tensor(1.00000e-05 *
#        6.1889)
# 286 tensor(1.00000e-05 *
#        6.1002)
# 287 tensor(1.00000e-05 *
#        6.0130)
# 288 tensor(1.00000e-05 *
#        5.9266)
# 289 tensor(1.00000e-05 *
#        5.8412)
# 290 tensor(1.00000e-05 *
#        5.7574)
# 291 tensor(1.00000e-05 *
#        5.6744)
# 292 tensor(1.00000e-05 *
#        5.5931)
# 293 tensor(1.00000e-05 *
#        5.5126)
# 294 tensor(1.00000e-05 *
#        5.4330)
# 295 tensor(1.00000e-05 *
#        5.3552)
# 296 tensor(1.00000e-05 *
#        5.2783)
# 297 tensor(1.00000e-05 *
#        5.2022)
# 298 tensor(1.00000e-05 *
#        5.1278)
# 299 tensor(1.00000e-05 *
#        5.0539)
# 300 tensor(1.00000e-05 *
#        4.9813)
# 301 tensor(1.00000e-05 *
#        4.9098)
# 302 tensor(1.00000e-05 *
#        4.8394)
# 303 tensor(1.00000e-05 *
#        4.7699)
# 304 tensor(1.00000e-05 *
#        4.7014)
# 305 tensor(1.00000e-05 *
#        4.6337)
# 306 tensor(1.00000e-05 *
#        4.5671)
# 307 tensor(1.00000e-05 *
#        4.5014)
# 308 tensor(1.00000e-05 *
#        4.4368)
# 309 tensor(1.00000e-05 *
#        4.3731)
# 310 tensor(1.00000e-05 *
#        4.3105)
# 311 tensor(1.00000e-05 *
#        4.2484)
# 312 tensor(1.00000e-05 *
#        4.1873)
# 313 tensor(1.00000e-05 *
#        4.1272)
# 314 tensor(1.00000e-05 *
#        4.0677)
# 315 tensor(1.00000e-05 *
#        4.0094)
# 316 tensor(1.00000e-05 *
#        3.9516)
# 317 tensor(1.00000e-05 *
#        3.8950)
# 318 tensor(1.00000e-05 *
#        3.8390)
# 319 tensor(1.00000e-05 *
#        3.7837)
# 320 tensor(1.00000e-05 *
#        3.7293)
# 321 tensor(1.00000e-05 *
#        3.6756)
# 322 tensor(1.00000e-05 *
#        3.6227)
# 323 tensor(1.00000e-05 *
#        3.5707)
# 324 tensor(1.00000e-05 *
#        3.5197)
# 325 tensor(1.00000e-05 *
#        3.4691)
# 326 tensor(1.00000e-05 *
#        3.4192)
# 327 tensor(1.00000e-05 *
#        3.3697)
# 328 tensor(1.00000e-05 *
#        3.3215)
# 329 tensor(1.00000e-05 *
#        3.2737)
# 330 tensor(1.00000e-05 *
#        3.2266)
# 331 tensor(1.00000e-05 *
#        3.1804)
# 332 tensor(1.00000e-05 *
#        3.1344)
# 333 tensor(1.00000e-05 *
#        3.0896)
# 334 tensor(1.00000e-05 *
#        3.0451)
# 335 tensor(1.00000e-05 *
#        3.0015)
# 336 tensor(1.00000e-05 *
#        2.9583)
# 337 tensor(1.00000e-05 *
#        2.9155)
# 338 tensor(1.00000e-05 *
#        2.8739)
# 339 tensor(1.00000e-05 *
#        2.8326)
# 340 tensor(1.00000e-05 *
#        2.7920)
# 341 tensor(1.00000e-05 *
#        2.7518)
# 342 tensor(1.00000e-05 *
#        2.7121)
# 343 tensor(1.00000e-05 *
#        2.6733)
# 344 tensor(1.00000e-05 *
#        2.6347)
# 345 tensor(1.00000e-05 *
#        2.5967)
# 346 tensor(1.00000e-05 *
#        2.5597)
# 347 tensor(1.00000e-05 *
#        2.5229)
# 348 tensor(1.00000e-05 *
#        2.4863)
# 349 tensor(1.00000e-05 *
#        2.4505)
# 350 tensor(1.00000e-05 *
#        2.4155)
# 351 tensor(1.00000e-05 *
#        2.3808)
# 352 tensor(1.00000e-05 *
#        2.3464)
# 353 tensor(1.00000e-05 *
#        2.3129)
# 354 tensor(1.00000e-05 *
#        2.2796)
# 355 tensor(1.00000e-05 *
#        2.2467)
# 356 tensor(1.00000e-05 *
#        2.2143)
# 357 tensor(1.00000e-05 *
#        2.1827)
# 358 tensor(1.00000e-05 *
#        2.1516)
# 359 tensor(1.00000e-05 *
#        2.1204)
# 360 tensor(1.00000e-05 *
#        2.0900)
# 361 tensor(1.00000e-05 *
#        2.0600)
# 362 tensor(1.00000e-05 *
#        2.0305)
# 363 tensor(1.00000e-05 *
#        2.0013)
# 364 tensor(1.00000e-05 *
#        1.9724)
# 365 tensor(1.00000e-05 *
#        1.9442)
# 366 tensor(1.00000e-05 *
#        1.9161)
# 367 tensor(1.00000e-05 *
#        1.8886)
# 368 tensor(1.00000e-05 *
#        1.8615)
# 369 tensor(1.00000e-05 *
#        1.8345)
# 370 tensor(1.00000e-05 *
#        1.8083)
# 371 tensor(1.00000e-05 *
#        1.7823)
# 372 tensor(1.00000e-05 *
#        1.7566)
# 373 tensor(1.00000e-05 *
#        1.7314)
# 374 tensor(1.00000e-05 *
#        1.7065)
# 375 tensor(1.00000e-05 *
#        1.6819)
# 376 tensor(1.00000e-05 *
#        1.6579)
# 377 tensor(1.00000e-05 *
#        1.6342)
# 378 tensor(1.00000e-05 *
#        1.6105)
# 379 tensor(1.00000e-05 *
#        1.5873)
# 380 tensor(1.00000e-05 *
#        1.5647)
# 381 tensor(1.00000e-05 *
#        1.5421)
# 382 tensor(1.00000e-05 *
#        1.5200)
# 383 tensor(1.00000e-05 *
#        1.4982)
# 384 tensor(1.00000e-05 *
#        1.4765)
# 385 tensor(1.00000e-05 *
#        1.4555)
# 386 tensor(1.00000e-05 *
#        1.4345)
# 387 tensor(1.00000e-05 *
#        1.4137)
# 388 tensor(1.00000e-05 *
#        1.3934)
# 389 tensor(1.00000e-05 *
#        1.3734)
# 390 tensor(1.00000e-05 *
#        1.3537)
# 391 tensor(1.00000e-05 *
#        1.3343)
# 392 tensor(1.00000e-05 *
#        1.3150)
# 393 tensor(1.00000e-05 *
#        1.2962)
# 394 tensor(1.00000e-05 *
#        1.2777)
# 395 tensor(1.00000e-05 *
#        1.2592)
# 396 tensor(1.00000e-05 *
#        1.2411)
# 397 tensor(1.00000e-05 *
#        1.2233)
# 398 tensor(1.00000e-05 *
#        1.2057)
# 399 tensor(1.00000e-05 *
#        1.1884)
# 400 tensor(1.00000e-05 *
#        1.1712)
# 401 tensor(1.00000e-05 *
#        1.1545)
# 402 tensor(1.00000e-05 *
#        1.1380)
# 403 tensor(1.00000e-05 *
#        1.1214)
# 404 tensor(1.00000e-05 *
#        1.1054)
# 405 tensor(1.00000e-05 *
#        1.0895)
# 406 tensor(1.00000e-05 *
#        1.0739)
# 407 tensor(1.00000e-05 *
#        1.0585)
# 408 tensor(1.00000e-05 *
#        1.0433)
# 409 tensor(1.00000e-05 *
#        1.0282)
# 410 tensor(1.00000e-05 *
#        1.0135)
# 411 tensor(1.00000e-06 *
#        9.9898)
# 412 tensor(1.00000e-06 *
#        9.8453)
# 413 tensor(1.00000e-06 *
#        9.7048)
# 414 tensor(1.00000e-06 *
#        9.5652)
# 415 tensor(1.00000e-06 *
#        9.4259)
# 416 tensor(1.00000e-06 *
#        9.2925)
# 417 tensor(1.00000e-06 *
#        9.1571)
# 418 tensor(1.00000e-06 *
#        9.0265)
# 419 tensor(1.00000e-06 *
#        8.8973)
# 420 tensor(1.00000e-06 *
#        8.7688)
# 421 tensor(1.00000e-06 *
#        8.6426)
# 422 tensor(1.00000e-06 *
#        8.5185)
# 423 tensor(1.00000e-06 *
#        8.3961)
# 424 tensor(1.00000e-06 *
#        8.2750)
# 425 tensor(1.00000e-06 *
#        8.1558)
# 426 tensor(1.00000e-06 *
#        8.0386)
# 427 tensor(1.00000e-06 *
#        7.9243)
# 428 tensor(1.00000e-06 *
#        7.8090)
# 429 tensor(1.00000e-06 *
#        7.6965)
# 430 tensor(1.00000e-06 *
#        7.5859)
# 431 tensor(1.00000e-06 *
#        7.4762)
# 432 tensor(1.00000e-06 *
#        7.3696)
# 433 tensor(1.00000e-06 *
#        7.2651)
# 434 tensor(1.00000e-06 *
#        7.1602)
# 435 tensor(1.00000e-06 *
#        7.0574)
# 436 tensor(1.00000e-06 *
#        6.9558)
# 437 tensor(1.00000e-06 *
#        6.8562)
# 438 tensor(1.00000e-06 *
#        6.7568)
# 439 tensor(1.00000e-06 *
#        6.6601)
# 440 tensor(1.00000e-06 *
#        6.5651)
# 441 tensor(1.00000e-06 *
#        6.4703)
# 442 tensor(1.00000e-06 *
#        6.3766)
# 443 tensor(1.00000e-06 *
#        6.2854)
# 444 tensor(1.00000e-06 *
#        6.1947)
# 445 tensor(1.00000e-06 *
#        6.1064)
# 446 tensor(1.00000e-06 *
#        6.0186)
# 447 tensor(1.00000e-06 *
#        5.9316)
# 448 tensor(1.00000e-06 *
#        5.8465)
# 449 tensor(1.00000e-06 *
#        5.7628)
# 450 tensor(1.00000e-06 *
#        5.6786)
# 451 tensor(1.00000e-06 *
#        5.5975)
# 452 tensor(1.00000e-06 *
#        5.5171)
# 453 tensor(1.00000e-06 *
#        5.4379)
# 454 tensor(1.00000e-06 *
#        5.3606)
# 455 tensor(1.00000e-06 *
#        5.2836)
# 456 tensor(1.00000e-06 *
#        5.2075)
# 457 tensor(1.00000e-06 *
#        5.1329)
# 458 tensor(1.00000e-06 *
#        5.0588)
# 459 tensor(1.00000e-06 *
#        4.9862)
# 460 tensor(1.00000e-06 *
#        4.9136)
# 461 tensor(1.00000e-06 *
#        4.8432)
# 462 tensor(1.00000e-06 *
#        4.7743)
# 463 tensor(1.00000e-06 *
#        4.7066)
# 464 tensor(1.00000e-06 *
#        4.6389)
# 465 tensor(1.00000e-06 *
#        4.5714)
# 466 tensor(1.00000e-06 *
#        4.5050)
# 467 tensor(1.00000e-06 *
#        4.4398)
# 468 tensor(1.00000e-06 *
#        4.3769)
# 469 tensor(1.00000e-06 *
#        4.3140)
# 470 tensor(1.00000e-06 *
#        4.2523)
# 471 tensor(1.00000e-06 *
#        4.1917)
# 472 tensor(1.00000e-06 *
#        4.1309)
# 473 tensor(1.00000e-06 *
#        4.0712)
# 474 tensor(1.00000e-06 *
#        4.0127)
# 475 tensor(1.00000e-06 *
#        3.9554)
# 476 tensor(1.00000e-06 *
#        3.8986)
# 477 tensor(1.00000e-06 *
#        3.8429)
# 478 tensor(1.00000e-06 *
#        3.7874)
# 479 tensor(1.00000e-06 *
#        3.7329)
# 480 tensor(1.00000e-06 *
#        3.6785)
# 481 tensor(1.00000e-06 *
#        3.6267)
# 482 tensor(1.00000e-06 *
#        3.5740)
# 483 tensor(1.00000e-06 *
#        3.5224)
# 484 tensor(1.00000e-06 *
#        3.4723)
# 485 tensor(1.00000e-06 *
#        3.4217)
# 486 tensor(1.00000e-06 *
#        3.3731)
# 487 tensor(1.00000e-06 *
#        3.3250)
# 488 tensor(1.00000e-06 *
#        3.2768)
# 489 tensor(1.00000e-06 *
#        3.2297)
# 490 tensor(1.00000e-06 *
#        3.1832)
# 491 tensor(1.00000e-06 *
#        3.1372)
# 492 tensor(1.00000e-06 *
#        3.0923)
# 493 tensor(1.00000e-06 *
#        3.0482)
# 494 tensor(1.00000e-06 *
#        3.0040)
# 495 tensor(1.00000e-06 *
#        2.9612)
# 496 tensor(1.00000e-06 *
#        2.9192)
# 497 tensor(1.00000e-06 *
#        2.8767)
# 498 tensor(1.00000e-06 *
#        2.8352)
# 499 tensor(1.00000e-06 *
#        2.7946)

# %% [markdown]
# ## After training

# %%
hour_var = Variable(torch.Tensor([[4.0]]))
y_pred = model(hour_var)
print("predict (after training)", 4, model(hour_var).data[0][0])
# Out:
# predict (after training) 4 tensor(8.0019)
